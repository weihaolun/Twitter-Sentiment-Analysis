# %%
import pandas as pd

# %%
# Read file as a dataframe.
negative_df = pd.read_csv("resources/filtered_data/negative.csv", index_col=[0])

# %%
# Extract "tweets" columns to a list.
negative_list = negative_df["tweets"].tolist()

# %%
# Distribution of this type of attitudes.
print(f'There are total {len(negative_list)} negative tweets.')
# Out:
# There are total 7054 negative tweets.

# %%
negative_list
# Out:
# ['@francesco_con40 2nd worst QB. DEFINITELY Tony Romo. The man who likes to share the ball with everyone. Including the other team.',
#  '@jacquelinemegan I\\u2019m sorry\\u002c I Heart Paris is no longer available at the Rockwell branch! You may call 8587000 to get a copy transferred! :)',
#  '@prodnose is this one of your little jokes like Elvis playing at the Marquee  next Tuesday?',
#  'Gold edges down ahead of US jobs data: SINGAPORE (Reuters) - Gold edged lower on Friday\\u002c with investors waiting for... http://t.co/CiqFona1',
#  'Monday before I leave Singapore\\u002c I am going to post something that might be offensive.',
#  '\\u2019Love-cheat\\u2019 Daniel Radcliffe splits with girlfriend Rosie Coker: London\\u002c Oct 19: Daniel Radcliffe has split wit... http://t.co/ZVlsK2HQ',
#  'Cardinal men take 4th in Cypress Point tournament: A good host never outshines their guests\\u002c but the Stanford me... http://t.co/JJGPNolq',
# ...
