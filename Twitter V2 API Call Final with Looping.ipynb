# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
from dotenv import load_dotenv
load_dotenv()

import os
bearer_token = os.environ.get("TOKEN")

# %%
os.environ['TOKEN'] = "AAAAAAAAAAAAAAAAAAAAABaiVAEAAAAApt9P1uPpaHahYsQUI%2FgelDldDV8%3Dr5dBsz4Xs13lFishbpkGjm67IFktN8Kn2ERyebLiV7vpsgp2P3"

# %%
def auth():
    return os.environ.get("TOKEN")

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """
    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date, next_token):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword, 
                    'start_time' : start_list[i], 
                    'end_time' : end_list[i],
                    'max_results' : max_results,
                    'tweet.fields': 'created_at',
                    'next_token': {}
                     }
    
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token=None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.get( url, auth=bearer_oauth, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that
        #Time created
        created_at = dateutil.parser.parse(tweet['created_at'])
        #Tweet ID
        tweet_id = tweet['id']
        #Tweet text
        text = tweet['text']
        # Assemble all data in a list
        res = [created_at, tweet_id, text]
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
# Load start and end times
time_range = pd.read_csv("TwitterAPI_start_end_times2.csv")
start_list = time_range['start_time'].tolist()
end_list = time_range['end_time'].tolist()

# %%
#Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "tesla lang:en -from:tesla -is:retweet"
start_list = start_list
end_list = end_list

max_results = 100

#Total number of tweets we collected from the loop
total_tweets = 0

# Create file
csvFile = open("API_data2.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['created_at','id','tweet'])
csvFile.close()

for i in range(0,len(start_list)):

    # Inputs
    count = 0 # Counting tweets per time period
    max_count = 200 # Max tweets per time period
    flag = True
    next_token = None
    
    # Check if flag is true
    while flag:
        # Check if max_count reached
        if count >= max_count:
            break
        print("-------------------")
        print("Token: ", next_token)
        url = create_url(keyword, start_list[i], end_list[i], next_token)
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
        result_count = json_response['meta']['result_count']

        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
            print("Next Token: ", next_token)
            if result_count is not None and result_count > 0 and next_token is not None:
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, "API_data2.csv")
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)                
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                print("-------------------")
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, "API_data2.csv")
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)
            
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        time.sleep(5)
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qnvzcw6lm2mqiyxi4dr567erh
# Start Date:  2021-11-08T05:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  100
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qnvzcw6lm2mqiyxi4dr567erh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qnvzbbuz7prk0rlpse9ltenp9
# Start Date:  2021-11-08T05:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  200
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qpyb0pdmeoovroo1zvpeqanb1
# Start Date:  2021-11-08T06:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  300
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qpyb0pdmeoovroo1zvpeqanb1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qpyaxok2ilkfij165r56ov6nx
# Start Date:  2021-11-08T06:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  400
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qpylz7vnpo6vvpklyu4012l4t
# Start Date:  2021-11-08T07:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  500
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qpylz7vnpo6vvpklyu4012l4t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qpylw6mydoyljycfa2epk1r3x
# Start Date:  2021-11-08T07:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  600
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qpz7dzpmxeh3ilohrnvq41w1p
# Start Date:  2021-11-08T08:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  700
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qpz7dzpmxeh3ilohrnvq41w1p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qpz7cggbwqem9dtfxi2mmkkfx
# Start Date:  2021-11-08T08:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  800
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qpzie19qxujt1sf5wjmwc2vel
# Start Date:  2021-11-08T09:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  900
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qpzie19qxujt1sf5wjmwc2vel
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qpzichskx1wu83ux7d7shgpz1
# Start Date:  2021-11-08T09:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  1000
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qq03ra9nvl4vlfrshfbsxicu5
# Start Date:  2021-11-08T10:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  1100
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qq03ra9nvl4vlfrshfbsxicu5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qq03pr07gsfwlbgnd582nt37h
# Start Date:  2021-11-08T10:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  1200
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qq0essis8k2skisa9cd5v0zgd
# Start Date:  2021-11-08T11:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  1300
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qq0essis8k2skisa9cd5v0zgd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8
00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  3996
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qu99k43olxij51pqzj9z4s0ot
# Start Date:  2021-11-08T23:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  4096
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qu99k43olxij51pqzj9z4s0ot
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qu99h3i30wuc1yvrt5kxdwvb1
# Start Date:  2021-11-08T23:00:00.000Z
# # of Tweets added from this response:  99
# Total # of Tweets added:  4195
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdv8qu99h3i30wuc1yvrt5kxdwvb1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdv8qu99e3j60rvfgtr72crtqx4l9
# Start Date:  2021-11-08T23:00:00.000Z
# # of Tweets added from this response:  100
# Total # of Tweets added:  4295
# -------------------
# Total number of results:  4295

# %%
# API for tweet counts
search_url = "https://api.twitter.com/2/tweets/counts/recent"

# Optional params: start_time,end_time,since_id,until_id,next_token,granularity
query_params = {'query': 'tesla lang:en', 'start_time': "2021-11-03T00:00:00.000Z", "end_time": "2021-11-09T00:00:00.000Z",'granularity': 'day'}

def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """
    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentTweetCountsPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.request("GET", search_url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

def main():
    json_response = connect_to_endpoint(search_url, query_params)
    return json_response
    #print(json.dumps(json_response, indent=4, sort_keys=True))

if __name__ == "__main__":
    main()
# Out:
# 200

# %%
response = main()
response = json.dumps(response, indent=4, sort_keys=True)
print(response)
# Out:
# 200
# {
#     "data": [
#         {
#             "end": "2021-11-04T00:00:00.000Z",
#             "start": "2021-11-03T00:00:00.000Z",
#             "tweet_count": 53148
#         },
#         {
#             "end": "2021-11-05T00:00:00.000Z",
#             "start": "2021-11-04T00:00:00.000Z",
#             "tweet_count": 54606
#         },
#         {
#             "end": "2021-11-06T00:00:00.000Z",
#             "start": "2021-11-05T00:00:00.000Z",
#             "tweet_count": 47726
#         },
#         {
#             "end": "2021-11-07T00:00:00.000Z",
#             "start": "2021-11-06T00:00:00.000Z",
#             "tweet_count": 64812
#         },
#         {
#             "end": "2021-11-08T00:00:00.000Z",
#             "start": "2021-11-07T00:00:00.000Z",
#             "tweet_count": 78984
#         },
#         {
#             "end": "2021-11-09T00:00:00.000Z",
#             "start": "2021-11-08T00:00:00.000Z",
#             "tweet_count": 74188
#         }
#     ],
#     "meta": {
#         "total_tweet_count": 373464
#     }
# }

# %%
x = json.loads(response)['data']
x
# Out:
# [{'end': '2021-11-04T00:00:00.000Z',
#   'start': '2021-11-03T00:00:00.000Z',
#   'tweet_count': 53148},
#  {'end': '2021-11-05T00:00:00.000Z',
#   'start': '2021-11-04T00:00:00.000Z',
#   'tweet_count': 54606},
#  {'end': '2021-11-06T00:00:00.000Z',
#   'start': '2021-11-05T00:00:00.000Z',
#   'tweet_count': 47726},
#  {'end': '2021-11-07T00:00:00.000Z',
#   'start': '2021-11-06T00:00:00.000Z',
#   'tweet_count': 64812},
#  {'end': '2021-11-08T00:00:00.000Z',
#   'start': '2021-11-07T00:00:00.000Z',
#   'tweet_count': 78984},
#  {'end': '2021-11-09T00:00:00.000Z',
#   'start': '2021-11-08T00:00:00.000Z',
#   'tweet_count': 74188}]

# %%
import csv 
cols = ["end", "start", "tweet_count"]
path = "API_count_data.csv"
with open(path, 'w') as f: 
    wr = csv.DictWriter(f, fieldnames = cols) 
    wr.writeheader() 
    wr.writerows(x)
