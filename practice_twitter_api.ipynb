# %%
# install dependencies
#!pip install tweepy
from config import API_KEY, API_KEY_Secret, Bearer_Token, Access_Token, Access_Token_Secret
import tweepy as tw
from tweepy.parsers import JSONParser

# %%
consumer_key = API_KEY
consumer_secret = API_KEY_Secret
access_token = Access_Token
access_token_secret = Access_Token_Secret

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

search_tweets = api.search_tweets(q="lysol",count=3)
# Out:
# statuses
# search_metadata

# %%
search_tweets
# Out:
# {'statuses': [{'created_at': 'Wed Oct 27 01:43:23 +0000 2021',
#    'id': 1453175461257875457,
#    'id_str': '1453175461257875457',
#    'text': '@RonFilipkowski Some Lysol next time every time he opens his mouth https://t.co/bXe9cFjeM0',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RonFilipkowski',
#       'name': 'Ron Filipkowski',
#       'id': 1298372735383605249,
#       'id_str': '1298372735383605249',
#       'indices': [0, 15]}],
#     'urls': [],
#     'media': [{'id': 1453175455616573441,
#       'id_str': '1453175455616573441',
#       'indices': [67, 90],
#       'media_url': 'http://pbs.twimg.com/tweet_video_thumb/FCq3YKxXoAEPLg3.jpg',
#       'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/FCq3YKxXoAEPLg3.jpg',
#       'url': 'https://t.co/bXe9cFjeM0',
#       'display_url': 'pic.twitter.com/bXe9cFjeM0',
# ...

# %%
search_tweets.keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %%
len(search_tweets["statuses"])
# Out:
# 3

# %%
tweets_data=[]
for i in range(len(search_tweets["statuses"])):
    tweet_dict={}
    tweet_date = search_tweets["statuses"][i]["created_at"]
    tweet_text = search_tweets["statuses"][i]["text"]
    
    tweet_dict["tweet_date"] = tweet_date
    tweet_dict["tweet_text"] = tweet_text
    
    tweets_data.append(tweet_dict)
    
    i += 1

# %%
for i in range(len(tweets_data)):
    print(tweets_data[i])
# Out:
# {'tweet_date': 'Wed Oct 27 01:43:23 +0000 2021', 'tweet_text': '@RonFilipkowski Some Lysol next time every time he opens his mouth https://t.co/bXe9cFjeM0'}
# {'tweet_date': 'Wed Oct 27 01:39:28 +0000 2021', 'tweet_text': 'I think I sprayed too much Lysol in my room I been choking for 30 min now 😹😹😹😹😩'}
# {'tweet_date': 'Wed Oct 27 01:36:56 +0000 2021', 'tweet_text': 'RT @Jmuilenburg6: @BridgeDanya Rural Idaho Middle School needs many basics (pencils, erasers, Kleenex,Lysol wipes, Ear buds, batteries). Ye…'}
